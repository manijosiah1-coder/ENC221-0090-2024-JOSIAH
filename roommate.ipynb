# %%
#class Roommate:
    def __init__(self,name,skincolour,city):
        self.name=name
        self.skincolour=skincolour
        self.city=city
    
    def roomie(self):
        print(" My roomie's name is " + self.name + " ,she's " + self.skincolour " and from " + self.city)
        
roomie1=Roomate("Anatalia","lighskin","Nairobi")
roomie1.roomie()
# Out:
#   Cell In[14], line 8
#     print(" My roomie's name is " + self.name + " ,she's " + self.skincolour " and from " + self.city)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
class Roommate:
    def __init__(self, name, skincolour, city):
        self.name = name
        self.skincolour = skincolour
        self.city = city

    def roomie(self):
        print("My roomie's name is " + self.name + 
              ", she's " + self.skincolour + 
              " and from " + self.city)

roomie1 = Roommate("Anatalia", "light skin", "Nairobi")
roomie1.roomie()
# Out:
# My roomie's name is Anatalia, she's light skin and from Nairobi
